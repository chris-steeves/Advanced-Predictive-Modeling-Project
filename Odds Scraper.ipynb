# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from bs4 import BeautifulSoup
import pandas as pd
import re
import os
import time
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from selenium.webdriver.common.by import By
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-8946c262dd0d> in <module>()
# ----> 1 from selenium import webdriver
#       2 from selenium.webdriver.common.keys import Keys
#       3 from selenium.webdriver.support.ui import WebDriverWait
#       4 from bs4 import BeautifulSoup
#       5 import pandas as pd
#
# ImportError: No module named selenium

# %%
# ## For game 12
# team_1_element = driver.find_element_by_xpath("/html/body/div[1]/div/div/div[1]/section/div/div[3]/div[3]/div[3]/div[1]/section/div/div[1]/div/div[2]/span")
# team_1 = team_1_element.text

# team_2_element = driver.find_element_by_xpath("/html/body/div[1]/div/div/div[1]/section/div/div[3]/div[3]/div[3]/div[1]/section/div/div[2]/div/div[2]/span")
# team_2 = team_2_element.text

# team_1_spread_element = driver.find_element_by_xpath("/html/body/div[1]/div/div/div[1]/section/div/div[3]/div[3]/div[3]/div[2]/div/div/div[2]/div/div/div/div/section[2]/main/div[1]/span/span[1]")
# team_1_spread = team_1_spread_element.text

# team_2_spread_element = driver.find_element_by_xpath("/html/body/div[1]/div/div/div[1]/section/div/div[3]/div[3]/div[3]/div[2]/div/div/div[2]/div/div/div/div/section[2]/main/div[2]/span/span[1]")
# team_2_spread = team_2_spread_element.text

# team_1_payout_element = driver.find_element_by_xpath("/html/body/div[1]/div/div/div[1]/section/div/div[3]/div[3]/div[3]/div[2]/div/div/div[2]/div/div/div/div/section[2]/main/div[1]/span/span[2]")
# team_1_payout = team_1_payout_element.text

# team_2_payout_element = driver.find_element_by_xpath("/html/body/div[1]/div/div/div[1]/section/div/div[3]/div[3]/div[3]/div[2]/div/div/div[2]/div/div/div/div/section[2]/main/div[2]/span/span[2]")
# team_2_payout = team_2_payout_element.text

# %%
# team_1

# %%
from datetime import date, timedelta

# a = date(2019, 8, 5)
# print(a+timedelta(1))

# type(a.isoformat().replace('-',''))

# %%
# only run once
driver = webdriver.Chrome(r"C:\Users\jakeh\Downloads\chromedriver_win32\chromedriver.exe")
driver.get("https://classic.sportsbookreview.com/betting-odds/consensus/?date=20190905")

# %%
game_day = date(2019, 9, 4)
game_lines = []
while game_day < date(2019, 11, 27):
    game_day += timedelta(1)
    try:
        driver.get("https://classic.sportsbookreview.com/betting-odds/consensus/?date=" + game_day.isoformat().replace('-',''))
        time.sleep(5)
        game_num = 3
        if (game_day.weekday() == 0 or game_day.weekday()== 3):
            team_1_element = driver.find_element_by_xpath("/html/body/form/div[3]/div/div/div[1]/div[1]/div/div/div/div/div[4]/div[2]/div[2]/div/div/div/div/div[2]/div[4]/div/div/div[5]/div[1]/span")
            team_1 = team_1_element.text

            team_2_element = driver.find_element_by_xpath("/html/body/form/div[3]/div/div/div[1]/div[1]/div/div/div/div/div[4]/div[2]/div[2]/div/div/div/div/div[2]/div[4]/div/div/div[5]/div[2]/span")
            team_2 = team_2_element.text

            team_1_spread_payout_element = driver.find_element_by_xpath("/html/body/form/div[3]/div/div/div[1]/div[1]/div/div/div/div/div[4]/div[2]/div[2]/div/div/div/div/div[2]/div[4]/div/div/div[6]/div[1]")
            team_1_spread = team_1_spread_payout_element.text.split(' ')[0]
            team_1_payout = team_1_spread_payout_element.text.split(' ')[1]

            team_2_spread_payout_element = driver.find_element_by_xpath("/html/body/form/div[3]/div/div/div[1]/div[1]/div/div/div/div/div[4]/div[2]/div[2]/div/div/div/div/div[2]/div[4]/div/div/div[6]/div[2]")
            team_2_spread = team_2_spread_payout_element.text.split(' ')[0]
            team_2_payout = team_2_spread_payout_element.text.split(' ')[1]

            game_lines.append([team_1, team_1_spread, team_1_payout, team_2, team_2_spread, team_2_payout, game_day.isoformat()])
            
        else: 
            while True:
                try:
                    team_1_element = driver.find_element_by_xpath("/html/body/form/div[3]/div/div/div[1]/div[1]/div/div/div/div/div[4]/div[2]/div[2]/div/div/div/div/div[2]/div[4]/div[" + str(game_num) + "]/div/div[5]/div[1]/span")
                    team_1 = team_1_element.text

                    team_2_element = driver.find_element_by_xpath("/html/body/form/div[3]/div/div/div[1]/div[1]/div/div/div/div/div[4]/div[2]/div[2]/div/div/div/div/div[2]/div[4]/div[" + str(game_num) + "]/div/div[5]/div[2]/span")
                    team_2 = team_2_element.text

                    print(game_day, team_1, team_2)

                    team_1_spread_payout_element = driver.find_element_by_xpath("/html/body/form/div[3]/div/div/div[1]/div[1]/div/div/div/div/div[4]/div[2]/div[2]/div/div/div/div/div[2]/div[4]/div[" + str(game_num) + "]/div/div[6]/div[1]")
                    team_1_spread = team_1_spread_payout_element.text.split(' ')[0]
                    team_1_payout = team_1_spread_payout_element.text.split(' ')[1]

                    team_2_spread_payout_element = driver.find_element_by_xpath("/html/body/form/div[3]/div/div/div[1]/div[1]/div/div/div/div/div[4]/div[2]/div[2]/div/div/div/div/div[2]/div[4]/div[" + str(game_num) + "]/div/div[6]/div[2]")
                    team_2_spread = team_2_spread_payout_element.text.split(' ')[0]
                    team_2_payout = team_2_spread_payout_element.text.split(' ')[1]


                    game_lines.append([team_1, team_1_spread, team_1_payout, team_2, team_2_spread, team_2_payout, game_day.isoformat()])

                except:
                    print("Now scraping", game_day + timedelta(1))
                    break
                game_num += 1

    except:
        pass

driver.close()
# Out:
# Now scraping 2019-09-07
# Now scraping 2019-09-08
# 2019-09-08 Kansas City Jacksonville
# 2019-09-08 L.A. Rams Carolina
# 2019-09-08 Atlanta Minnesota
# 2019-09-08 Tennessee Cleveland
# 2019-09-08 Baltimore Miami
# 2019-09-08 Cincinnati Seattle
# 2019-09-08 Indianapolis L.A. Chargers
# 2019-09-08 San Francisco Tampa Bay
# 2019-09-08 Detroit Arizona
# 2019-09-08 N.Y. Giants Dallas
# 2019-09-08 Pittsburgh New England
# Now scraping 2019-09-09
# Now scraping 2019-09-11
# Now scraping 2019-09-12
# Now scraping 2019-09-14
# Now scraping 2019-09-15
# 2019-09-15 Dallas Washington
# 2019-09-15 Seattle Pittsburgh
# 2019-09-15 Minnesota Green Bay
# 2019-09-15 Buffalo N.Y. Giants
# 2019-09-15 Jacksonville Houston
# 2019-09-15 Arizona Baltimore
# 2019-09-15 San Francisco Cincinnati
# 2019-09-15 New England Miami
# 2019-09-15 Kansas City Oakland
# 2019-09-15 Chicago Denver
# 2019-09-15 New Orleans L.A. Rams
# 2019-09-15 Philadelphia Atlanta
# Now scraping 2019-09-16
# Now scraping 2019-09-18
# Now scraping 2019-09-19
# Now scraping 2019-09-21
# Now scraping 2019-09-22
# 2019-09-22 Baltimore Kansas City
# 2019-09-22 Cincinnati Buffalo
# 2019-09-22 N.Y. Jets New England
# 2019-09-22 Detroit Philadelphia
# 2019-09-22 Oakland Minnesota
# 2019-09-22 Miami Dallas
# 2019-09-22 N.Y. Giants Tampa Bay
# 2019-09-22 Carolina Arizona
# 2019-09-22 Pittsburgh San Francisco
# 2019-09-22 Houston L.A. Chargers
# 2019-09-22 New Orleans Seattle
# 2019-09-22 L.A. Rams Cleveland
# Now scraping 2019-09-23
# Now scraping 2019-09-25
# Now scraping 2019-09-26
# Now scraping 2019-09-28
# Now scraping 2019-09-29
# 2019-09-29 Kansas City Detroit
# 2019-09-29 New England Buffalo
# 2019-09-29 L.A. Chargers Miami
# 2019-09-29 Oakland Indianapolis
# 2019-09-29 Tennessee Atlanta
# 2019-09-29 Washington N.Y. Giants
# 2019-09-29 Tampa Bay L.A. Rams
# 2019-09-29 Seattle Arizona
# 2019-09-29 Minnesota Chicago
# 2019-09-29 Jacksonville Denver
# 2019-09-29 Dallas New Orleans
# Now scraping 2019-09-30
# Now scraping 2019-10-02
# Now scraping 2019-10-03
# Now scraping 2019-10-05
# Now scraping 2019-10-06
# 2019-10-06 Baltimore Pittsburgh
# 2019-10-06 New England Washington
# 2019-10-06 Arizona Cincinnati
# 2019-10-06 Jacksonville Carolina
# 2019-10-06 Tampa Bay New Orleans
# 2019-10-06 N.Y. Jets Philadelphia
# 2019-10-06 Chicago Oakland
# 2019-10-06 Minnesota N.Y. Giants
# 2019-10-06 Denver L.A. Chargers
# 2019-10-06 Green Bay Dallas
# 2019-10-06 Indianapolis Kansas City
# Now scraping 2019-10-07
# Now scraping 2019-10-09
# Now scraping 2019-10-10
# Now scraping 2019-10-12
# Now scraping 2019-10-13
# 2019-10-13 Seattle Cleveland
# 2019-10-13 Cincinnati Baltimore
# 2019-10-13 New Orleans Jacksonville
# 2019-10-13 Philadelphia Minnesota
# 2019-10-13 Washington Miami
# 2019-10-13 San Francisco L.A. Rams
# 2019-10-13 Atlanta Arizona
# 2019-10-13 Dallas N.Y. Jets
# 2019-10-13 Tennessee Denver
# 2019-10-13 Pittsburgh L.A. Chargers
# Now scraping 2019-10-14
# Now scraping 2019-10-16
# Now scraping 2019-10-17
# Now scraping 2019-10-19
# Now scraping 2019-10-20
# 2019-10-20 Arizona N.Y. Giants
# 2019-10-20 San Francisco Washington
# 2019-10-20 Jacksonville Cincinnati
# 2019-10-20 Oakland Green Bay
# 2019-10-20 Miami Buffalo
# 2019-10-20 L.A. Rams Atlanta
# 2019-10-20 L.A. Chargers Tennessee
# 2019-10-20 Baltimore Seattle
# 2019-10-20 New Orleans Chicago
# 2019-10-20 Philadelphia Dallas
# Now scraping 2019-10-21
# Now scraping 2019-10-23
# Now scraping 2019-10-24
# Now scraping 2019-10-26
# Now scraping 2019-10-27
# 2019-10-27 Arizona New Orleans
# 2019-10-27 L.A. Chargers Chicago
# 2019-10-27 Cincinnati L.A. Rams
# 2019-10-27 N.Y. Jets Jacksonville
# 2019-10-27 N.Y. Giants Detroit
# 2019-10-27 Tampa Bay Tennessee
# 2019-10-27 Philadelphia Buffalo
# 2019-10-27 Carolina San Francisco
# 2019-10-27 Oakland Houston
# 2019-10-27 Cleveland New England
# 2019-10-27 Green Bay Kansas City
# Now scraping 2019-10-28
# Now scraping 2019-10-30
# Now scraping 2019-10-31
# Now scraping 2019-11-02
# Now scraping 2019-11-03
# 2019-11-03 Tennessee Carolina
# 2019-11-03 Chicago Philadelphia
# 2019-11-03 Minnesota Kansas City
# 2019-11-03 Washington Buffalo
# 2019-11-03 Indianapolis Pittsburgh
# 2019-11-03 Tampa Bay Seattle
# 2019-11-03 Detroit Oakland
# 2019-11-03 Cleveland Denver
# 2019-11-03 Green Bay L.A. Chargers
# 2019-11-03 New England Baltimore
# Now scraping 2019-11-04
# Now scraping 2019-11-06
# Now scraping 2019-11-07
# Now scraping 2019-11-09
# Now scraping 2019-11-10
# 2019-11-10 Atlanta New Orleans
# 2019-11-10 N.Y. Giants N.Y. Jets
# 2019-11-10 Kansas City Tennessee
# 2019-11-10 Arizona Tampa Bay
# 2019-11-10 Detroit Chicago
# 2019-11-10 Miami Indianapolis
# 2019-11-10 L.A. Rams Pittsburgh
# 2019-11-10 Carolina Green Bay
# 2019-11-10 Minnesota Dallas
# Now scraping 2019-11-11
# Now scraping 2019-11-13
# Now scraping 2019-11-14
# Now scraping 2019-11-16
# Now scraping 2019-11-17
# 2019-11-17 Jacksonville Indianapolis
# 2019-11-17 Denver Minnesota
# 2019-11-17 Houston Baltimore
# 2019-11-17 N.Y. Jets Washington
# 2019-11-17 Atlanta Carolina
# 2019-11-17 Buffalo Miami
# 2019-11-17 Arizona San Francisco
# 2019-11-17 Cincinnati Oakland
# 2019-11-17 New England Philadelphia
# 2019-11-17 Chicago L.A. Rams
# Now scraping 2019-11-18
# Now scraping 2019-11-20
# Now scraping 2019-11-21
# Now scraping 2019-11-23
# Now scraping 2019-11-24
# 2019-11-24 N.Y. Giants Chicago
# 2019-11-24 Seattle Philadelphia
# 2019-11-24 Carolina New Orleans
# 2019-11-24 Oakland N.Y. Jets
# 2019-11-24 Denver Buffalo
# 2019-11-24 Detroit Washington
# 2019-11-24 Pittsburgh Cincinnati
# 2019-11-24 Jacksonville Tennessee
# 2019-11-24 Dallas New England
# 2019-11-24 Green Bay San Francisco
# Now scraping 2019-11-25
# Now scraping 2019-11-27
# Now scraping 2019-11-28

# %%
game_lines
# Out:
# [['Green Bay', '+3½', '-115', 'Chicago', '-3½', '+105', '2019-09-05'],
#  ['Kansas City', '-3½', '+100', 'Jacksonville', '+3½', '-110', '2019-09-08'],
#  ['L.A. Rams', '-1½', '-105', 'Carolina', '+1½', '-105', '2019-09-08'],
#  ['Atlanta', '+3½', '-110', 'Minnesota', '-3½', '+100', '2019-09-08'],
#  ['Tennessee', '+5½', '-109', 'Cleveland', '-5½', '-101', '2019-09-08'],
#  ['Baltimore', '-7', '-105', 'Miami', '+7', '-105', '2019-09-08'],
#  ['Cincinnati', '+9', '-105', 'Seattle', '-9', '-105', '2019-09-08'],
#  ['Indianapolis', '+6', '-105', 'L.A. Chargers', '-6', '-105', '2019-09-08'],
#  ['San Francisco', '+1', '-105', 'Tampa Bay', '-1', '-105', '2019-09-08'],
#  ['Detroit', '-2½', '-120', 'Arizona', '+2½', '+110', '2019-09-08'],
#  ['N.Y. Giants', '+7', '-110', 'Dallas', '-7', '+100', '2019-09-08'],
#  ['Pittsburgh', '+5½', '-107', 'New England', '-5½', '-103', '2019-09-08'],
#  ['Houston', '+6½', '+102', 'New Orleans', '-6½', '-112', '2019-09-09'],
#  ['Tampa Bay', '+6½', '-108', 'Carolina', '-6½', '-102', '2019-09-12'],
#  ['Dallas', '-6½', '-105', 'Washington', '+6½', '-105', '2019-09-15'],
#  ['Seattle', '+4', '-105', 'Pittsburgh', '-4', '-105', '2019-09-15'],
#  ['Minnesota', '+3', '-105', 'Green Bay', '-3', '-105', '2019-09-15'],
#  ['Buffalo', '-1', '-108', 'N.Y. Giants', '+1', '-102', '2019-09-15'],
#  ['Jacksonville', '+7', '-105', 'Houston', '-7', '-105', '2019-09-15'],
#  ['Arizona', '+13', '-105', 'Baltimore', '-13', '-105', '2019-09-15'],
#  ['San Francisco', '+1', '-105', 'Cincinnati', '-1', '-105', '2019-09-15'],
#  ['New England', '-18', '-105', 'Miami', '+18', '-105', '2019-09-15'],
#  ['Kansas City', '-6½', '-110', 'Oakland', '+6½', '+100', '2019-09-15'],
#  ['Chicago', '-2½', '-120', 'Denver', '+2½', '+110', '2019-09-15'],
#  ['New Orleans', '+2', '-105', 'L.A. Rams', '-2', '-105', '2019-09-15'],
#  ['Philadelphia', '-1', '-106', 'Atlanta', '+1', '-104', '2019-09-15'],
#  ['Cleveland', '-6½', '-112', 'N.Y. Jets', '+6½', '+102', '2019-09-16'],
#  ['Tennessee', '-2', '-103', 'Jacksonville', '+2', '-107', '2019-09-19'],
#  ['Baltimore', '+4', '-102', 'Kansas City', '-4', '-108', '2019-09-22'],
#  ['Cincinnati', '+6', '-110', 'Buffalo', '-6', '+100', '2019-09-22'],
#  ['N.Y. Jets', '+21', '-110', 'New England', '-21', '+100', '2019-09-22'],
#  ['Detroit', '+4', '-105', 'Philadelphia', '-4', '-105', '2019-09-22'],
#  ['Oakland', '+9', '-109', 'Minnesota', '-9', '-101', '2019-09-22'],
#  ['Miami', '+22', '-105', 'Dallas', '-22', '-105', '2019-09-22'],
#  ['N.Y. Giants', '+5', '-101', 'Tampa Bay', '-5', '-109', '2019-09-22'],
#  ['Carolina', '+2½', '-107', 'Arizona', '-2½', '-103', '2019-09-22'],
#  ['Pittsburgh', '+6', '-105', 'San Francisco', '-6', '-105', '2019-09-22'],
#  ['Houston', '+3', '+100', 'L.A. Chargers', '-3', '-110', '2019-09-22'],
#  ['New Orleans', '+5', '-105', 'Seattle', '-5', '-105', '2019-09-22'],
#  ['L.A. Rams', '-4½', '-102', 'Cleveland', '+4½', '-108', '2019-09-22'],
#  ['Chicago', '-5', '-105', 'Washington', '+5', '-105', '2019-09-23'],
#  ['Philadelphia', '+3½', '-107', 'Green Bay', '-3½', '-103', '2019-09-26'],
#  ['Kansas City', '-7', '-110', 'Detroit', '+7', '+100', '2019-09-29'],
#  ['New England', '-7', '-108', 'Buffalo', '+7', '-102', '2019-09-29'],
#  ['L.A. Chargers', '-14½', '-108', 'Miami', '+14½', '-102', '2019-09-29'],
#  ['Oakland', '+6', '-108', 'Indianapolis', '-6', '-102', '2019-09-29'],
#  ['Tennessee', '+3', '+108', 'Atlanta', '-3', '-118', '2019-09-29'],
#  ['Washington', '+3', '+100', 'N.Y. Giants', '-3', '-110', '2019-09-29'],
#  ['Tampa Bay', '+9', '-109', 'L.A. Rams', '-9', '-101', '2019-09-29'],
#  ['Seattle', '-6', '-102', 'Arizona', '+6', '-108', '2019-09-29'],
#  ['Minnesota', '+1', '-112', 'Chicago', '-1', '+102', '2019-09-29'],
#  ['Jacksonville', '+2½', '+103', 'Denver', '-2½', '-113', '2019-09-29'],
#  ['Dallas', '-2½', '-110', 'New Orleans', '+2½', '+100', '2019-09-29'],
#  ['Cincinnati', '+3½', '-108', 'Pittsburgh', '-3½', '-102', '2019-09-30'],
#  ['L.A. Rams', '+1', '-102', 'Seattle', '-1', '-108', '2019-10-03'],
#  ['Baltimore', '-3', '-120', 'Pittsburgh', '+3', '+110', '2019-10-06'],
#  ['New England', '-16½', '-108', 'Washington', '+16½', '-102', '2019-10-06'],
#  ['Arizona', '+3', '+100', 'Cincinnati', '-3', '-110', '2019-10-06'],
#  ['Jacksonville', '+3', '+105', 'Carolina', '-3', '-115', '2019-10-06'],
#  ['Tampa Bay', '+3', '-110', 'New Orleans', '-3', '+100', '2019-10-06'],
#  ['N.Y. Jets', '+14', '-108', 'Philadelphia', '-14', '-102', '2019-10-06'],
#  ['Chicago', '-6½', '-115', 'Oakland', '+6½', '+105', '2019-10-06'],
#  ['Minnesota', '-6', '-105', 'N.Y. Giants', '+6', '-105', '2019-10-06'],
#  ['Denver', '+4½', '-105', 'L.A. Chargers', '-4½', '-105', '2019-10-06'],
#  ['Green Bay', '+3½', '-115', 'Dallas', '-3½', '+105', '2019-10-06'],
#  ['Indianapolis', '+10½', '-105', 'Kansas City', '-10½', '-105', '2019-10-06'],
#  ['Cleveland', '+5', '-105', 'San Francisco', '-5', '-105', '2019-10-07'],
#  ['N.Y. Giants', '+17', '-109', 'New England', '-17', '-101', '2019-10-10'],
#  ['Seattle', '+1', '-107', 'Cleveland', '-1', '-103', '2019-10-13'],
#  ['Cincinnati', '+10½', '-104', 'Baltimore', '-10½', '-106', '2019-10-13'],
#  ['New Orleans', '+3', '-115', 'Jacksonville', '-3', '+105', '2019-10-13'],
#  ['Philadelphia', '+3½', '-109', 'Minnesota', '-3½', '-101', '2019-10-13'],
#  ['Washington', '-6', '-103', 'Miami', '+6', '-107', '2019-10-13'],
#  ['San Francisco', '+3', '-108', 'L.A. Rams', '-3', '-102', '2019-10-13'],
#  ['Atlanta', '-3', '-105', 'Arizona', '+3', '-105', '2019-10-13'],
#  ['Dallas', '-7', '-105', 'N.Y. Jets', '+7', '-105', '2019-10-13'],
#  ['Tennessee', '+1', '-104', 'Denver', '-1', '-106', '2019-10-13'],
#  ['Pittsburgh', '+6', '-101', 'L.A. Chargers', '-6', '-109', '2019-10-13'],
#  ['Detroit', '+3½', '-105', 'Green Bay', '-3½', '-105', '2019-10-14'],
#  ['Kansas City', '-3', '+102', 'Denver', '+3', '-112', '2019-10-17'],
#  ['Arizona', '+3½', '-105', 'N.Y. Giants', '-3½', '-105', '2019-10-20'],
#  ['San Francisco', '-10', '-101', 'Washington', '+10', '-109', '2019-10-20'],
#  ['Jacksonville', '-4½', '-102', 'Cincinnati', '+4½', '-108', '2019-10-20'],
#  ['Oakland', '+6', '-109', 'Green Bay', '-6', '-101', '2019-10-20'],
#  ['Miami', '+17', '-101', 'Buffalo', '-17', '-109', '2019-10-20'],
#  ['L.A. Rams', '-3', '-115', 'Atlanta', '+3', '+105', '2019-10-20'],
#  ['L.A. Chargers', '+3', '-105', 'Tennessee', '-3', '-105', '2019-10-20'],
#  ['Baltimore', '+3', '-103', 'Seattle', '-3', '-107', '2019-10-20'],
#  ['New Orleans', '+4½', '-108', 'Chicago', '-4½', '-102', '2019-10-20'],
#  ['Philadelphia', '+3', '-105', 'Dallas', '-3', '-105', '2019-10-20'],
#  ['New England', '-9½', '-105', 'N.Y. Jets', '+9½', '-105', '2019-10-21'],
#  ['Washington', '+16½', '-108', 'Minnesota', '-16½', '-102', '2019-10-24'],
#  ['Arizona', '+12½', '-108', 'New Orleans', '-12½', '-102', '2019-10-27'],
#  ['L.A. Chargers', '+3½', '-110', 'Chicago', '-3½', '+100', '2019-10-27'],
#  ['Cincinnati', '+12', '-107', 'L.A. Rams', '-12', '-103', '2019-10-27'],
#  ['N.Y. Jets', '+7', '-110', 'Jacksonville', '-7', '+100', '2019-10-27'],
#  ['N.Y. Giants', '+6', '-103', 'Detroit', '-6', '-107', '2019-10-27'],
#  ['Tampa Bay', '+2', '-105', 'Tennessee', '-2', '-105', '2019-10-27'],
#  ['Philadelphia', '+1', '-105', 'Buffalo', '-1', '-105', '2019-10-27'],
#  ['Carolina', '+4', '-105', 'San Francisco', '-4', '-105', '2019-10-27'],
#  ['Oakland', '+5', '-105', 'Houston', '-5', '-105', '2019-10-27'],
#  ['Cleveland', '+10', '-110', 'New England', '-10', '+100', '2019-10-27'],
#  ['Green Bay', '-5½', '-105', 'Kansas City', '+5½', '-105', '2019-10-27'],
#  ['Miami', '+14', '-109', 'Pittsburgh', '-14', '-101', '2019-10-28'],
#  ['San Francisco', '-10', '-109', 'Arizona', '+10', '-101', '2019-10-31'],
#  ['Tennessee', '+3½', '-110', 'Carolina', '-3½', '+100', '2019-11-03'],
#  ['Chicago', '+5', '-103', 'Philadelphia', '-5', '-107', '2019-11-03'],
#  ['Minnesota', '-5½', '-103', 'Kansas City', '+5½', '-107', '2019-11-03'],
#  ['Washington', '+10½', '-108', 'Buffalo', '-10½', '-102', '2019-11-03'],
#  ['Indianapolis', '+1', '-102', 'Pittsburgh', '-1', '-108', '2019-11-03'],
#  ['Tampa Bay', '+4', '-105', 'Seattle', '-4', '-105', '2019-11-03'],
#  ['Detroit', '+2½', '+105', 'Oakland', '-2½', '-115', '2019-11-03'],
#  ['Cleveland', '-4', '-102', 'Denver', '+4', '-108', '2019-11-03'],
#  ['Green Bay', '-4', '-105', 'L.A. Chargers', '+4', '-105', '2019-11-03'],
#  ['New England', '-3', '-109', 'Baltimore', '+3', '-101', '2019-11-03'],
#  ['Dallas', '-6½', '-110', 'N.Y. Giants', '+6½', '+100', '2019-11-04'],
#  ['L.A. Chargers', '-1½', '-104', 'Oakland', '+1½', '-106', '2019-11-07'],
#  ['Atlanta', '+13½', '-105', 'New Orleans', '-13½', '-105', '2019-11-10'],
#  ['N.Y. Giants', '-2½', '-120', 'N.Y. Jets', '+2½', '+110', '2019-11-10'],
#  ['Kansas City', '-5', '-105', 'Tennessee', '+5', '-105', '2019-11-10'],
#  ['Arizona', '+5½', '-105', 'Tampa Bay', '-5½', '-105', '2019-11-10'],
#  ['Detroit', '+6½', '-105', 'Chicago', '-6½', '-105', '2019-11-10'],
#  ['Miami', '+11', '-105', 'Indianapolis', '-11', '-105', '2019-11-10'],
#  ['L.A. Rams', '-4½', '-108', 'Pittsburgh', '+4½', '-102', '2019-11-10'],
#  ['Carolina', '+5½', '-105', 'Green Bay', '-5½', '-105', '2019-11-10'],
#  ['Minnesota', '+3', '+110', 'Dallas', '-3', '-120', '2019-11-10'],
#  ['Seattle', '+6½', '-105', 'San Francisco', '-6½', '-105', '2019-11-11'],
#  ['Pittsburgh', '+3', '+100', 'Cleveland', '-3', '-110', '2019-11-14'],
#  ['Jacksonville', '+2½', '-105', 'Indianapolis', '-2½', '-105', '2019-11-17'],
#  ['Denver', '+9½', '-102', 'Minnesota', '-9½', '-108', '2019-11-17'],
#  ['Houston', '+4½', '-107', 'Baltimore', '-4½', '-103', '2019-11-17'],
#  ['N.Y. Jets', '+1½', '-105', 'Washington', '-1½', '-105', '2019-11-17'],
#  ['Atlanta', '+4', '-108', 'Carolina', '-4', '-102', '2019-11-17'],
#  ['Buffalo', '-7', '-105', 'Miami', '+7', '-105', '2019-11-17'],
#  ['Arizona', '+9½', '+100', 'San Francisco', '-9½', '-110', '2019-11-17'],
#  ['Cincinnati', '+13', '-105', 'Oakland', '-13', '-105', '2019-11-17'],
#  ['New England', '-4½', '-101', 'Philadelphia', '+4½', '-109', '2019-11-17'],
#  ['Chicago', '+5½', '-108', 'L.A. Rams', '-5½', '-102', '2019-11-17'],
#  ['Kansas City', '-5½', '-102', 'L.A. Chargers', '+5½', '-108', '2019-11-18'],
#  ['Indianapolis', '+3½', '-101', 'Houston', '-3½', '-109', '2019-11-21'],
#  ['N.Y. Giants', '+6', '-109', 'Chicago', '-6', '-101', '2019-11-24'],
#  ['Seattle', '-1', '+102', 'Philadelphia', '+1', '-112', '2019-11-24'],
#  ['Carolina', '+10', '-109', 'New Orleans', '-10', '-101', '2019-11-24'],
#  ['Oakland', '-3', '-125', 'N.Y. Jets', '+3', '+115', '2019-11-24'],
#  ['Denver', '+4', '-108', 'Buffalo', '-4', '-102', '2019-11-24'],
#  ['Detroit', '-4', '-101', 'Washington', '+4', '-109', '2019-11-24'],
#  ['Pittsburgh', '-6', '-105', 'Cincinnati', '+6', '-105', '2019-11-24'],
#  ['Jacksonville', '+4½', '-107', 'Tennessee', '-4½', '-103', '2019-11-24'],
#  ['Dallas', '+5½', '-105', 'New England', '-5½', '-105', '2019-11-24'],
#  ['Green Bay', '+3', '+110', 'San Francisco', '-3', '-120', '2019-11-24'],
#  ['Baltimore', '-3', '-115', 'L.A. Rams', '+3', '+105', '2019-11-25']]

# %%
import copy
df = pd.DataFrame(game_lines, columns = ['Away','Away_Spread','Away_Payout','Home','Home_Spread', 'Home_Payout', "Date"])#.replace('PK', 0)# .replace('-7½','-7.5')
df_copy = copy.deepcopy(df)
df
# Out:
#              Away Away_Spread Away_Payout           Home Home_Spread  \
# 0       Green Bay         +3½        -115        Chicago         -3½
# 1     Kansas City         -3½        +100   Jacksonville         +3½
# 2       L.A. Rams         -1½        -105       Carolina         +1½
# 3         Atlanta         +3½        -110      Minnesota         -3½
# 4       Tennessee         +5½        -109      Cleveland         -5½
# ..            ...         ...         ...            ...         ...
# 146    Pittsburgh          -6        -105     Cincinnati          +6
# 147  Jacksonville         +4½        -107      Tennessee         -4½
# 148        Dallas         +5½        -105    New England         -5½
# 149     Green Bay          +3        +110  San Francisco          -3
# 150     Baltimore          -3        -115      L.A. Rams          +3
#
#     Home_Payout        Date
# 0          +105  2019-09-05
# 1          -110  2019-09-08
# 2          -105  2019-09-08
# 3          +100  2019-09-08
# 4          -101  2019-09-08
# ..          ...         ...
# 146        -105  2019-11-24
# 147        -103  2019-11-24
# 148        -105  2019-11-24
# 149        -120  2019-11-24
# 150        +105  2019-11-25
#
# [151 rows x 7 columns]

# %%
# only run once
driver = webdriver.Chrome(r"C:\Users\jakeh\Downloads\chromedriver_win32\chromedriver.exe")
driver.get("https://classic.sportsbookreview.com/betting-odds/consensus/?date=20191128")

# %%
game_day = date(2019, 11, 26)
game_lines = []
while game_day < date(2019, 12, 11):
    game_day += timedelta(1)
    try:
        driver.get("https://classic.sportsbookreview.com/betting-odds/consensus/?date=" + game_day.isoformat().replace('-',''))
        time.sleep(5)
        game_num = 1
        if (game_day.weekday() == 0):
            team_1_element = driver.find_element_by_xpath("/html/body/form/div[3]/div/div/div[1]/div[1]/div/div/div/div/div[4]/div[2]/div[2]/div/div/div/div/div[2]/div[1]/div/div/div[5]/div[1]/span")
            team_1 = team_1_element.text

            team_2_element = driver.find_element_by_xpath("/html/body/form/div[3]/div/div/div[1]/div[1]/div/div/div/div/div[4]/div[2]/div[2]/div/div/div/div/div[2]/div[1]/div/div/div[5]/div[2]/span")
            team_2 = team_2_element.text

            team_1_spread_payout_element = driver.find_element_by_xpath("/html/body/form/div[3]/div/div/div[1]/div[1]/div/div/div/div/div[4]/div[2]/div[2]/div/div/div/div/div[2]/div[1]/div/div/div[6]/div[1]")
            team_1_spread = team_1_spread_payout_element.text.split(' ')[0]
            team_1_payout = team_1_spread_payout_element.text.split(' ')[1]

            team_2_spread_payout_element = driver.find_element_by_xpath("/html/body/form/div[3]/div/div/div[1]/div[1]/div/div/div/div/div[4]/div[2]/div[2]/div/div/div/div/div[2]/div[1]/div/div/div[6]/div[2]")
            team_2_spread = team_2_spread_payout_element.text.split(' ')[0]
            team_2_payout = team_2_spread_payout_element.text.split(' ')[1]

            game_lines.append([team_1, team_1_spread, team_1_payout, team_2, team_2_spread, team_2_payout, game_day.isoformat()])
            
        else: 
            while True:
                try:
                    team_1_element = driver.find_element_by_xpath("/html/body/form/div[3]/div/div/div[1]/div[1]/div/div/div/div/div[4]/div[2]/div[2]/div/div/div/div/div[2]/div[1]/div[" + str(game_num) + "]/div/div[5]/div[1]/span")
                    team_1 = team_1_element.text

                    team_2_element = driver.find_element_by_xpath("/html/body/form/div[3]/div/div/div[1]/div[1]/div/div/div/div/div[4]/div[2]/div[2]/div/div/div/div/div[2]/div[1]/div[" + str(game_num) + "]/div/div[5]/div[2]/span")
                    team_2 = team_2_element.text

                    print(game_day, team_1, team_2)

                    team_1_spread_payout_element = driver.find_element_by_xpath("/html/body/form/div[3]/div/div/div[1]/div[1]/div/div/div/div/div[4]/div[2]/div[2]/div/div/div/div/div[2]/div[1]/div[" + str(game_num) + "]/div/div[6]/div[1]")
                    team_1_spread = team_1_spread_payout_element.text.split(' ')[0]
                    team_1_payout = team_1_spread_payout_element.text.split(' ')[1]

                    team_2_spread_payout_element = driver.find_element_by_xpath("/html/body/form/div[3]/div/div/div[1]/div[1]/div/div/div/div/div[4]/div[2]/div[2]/div/div/div/div/div[2]/div[1]/div[" + str(game_num) + "]/div/div[6]/div[2]")
                    team_2_spread = team_2_spread_payout_element.text.split(' ')[0]
                    team_2_payout = team_2_spread_payout_element.text.split(' ')[1]


                    game_lines.append([team_1, team_1_spread, team_1_payout, team_2, team_2_spread, team_2_payout, game_day.isoformat()])

                except:
                    print("Now scraping", game_day + timedelta(1))
                    break
                game_num += 1

    except:
        pass

driver.close()
# Out:
# Now scraping 2019-11-28
# 2019-11-28 Chicago Detroit
# 2019-11-28 Buffalo Dallas
# 2019-11-28 New Orleans Atlanta
# Now scraping 2019-11-29
# Now scraping 2019-11-30
# Now scraping 2019-12-01
# 2019-12-01 Philadelphia Miami
# 2019-12-01 N.Y. Jets Cincinnati
# 2019-12-01 Tennessee Indianapolis
# 2019-12-01 Cleveland Pittsburgh
# 2019-12-01 Washington Carolina
# 2019-12-01 Green Bay N.Y. Giants
# 2019-12-01 San Francisco Baltimore
# 2019-12-01 Tampa Bay Jacksonville
# 2019-12-01 L.A. Rams Arizona
# 2019-12-01 Oakland Kansas City
# 2019-12-01 L.A. Chargers Denver
# 2019-12-01 New England Houston
# Now scraping 2019-12-02
# Now scraping 2019-12-04
# Now scraping 2019-12-05
# 2019-12-05 Dallas Chicago
# Now scraping 2019-12-06
# Now scraping 2019-12-07
# Now scraping 2019-12-08
# 2019-12-08 Washington Green Bay
# Now scraping 2019-12-09
# Now scraping 2019-12-11
# Now scraping 2019-12-12

# %%
df_future = pd.DataFrame(game_lines, columns = ['Away','Away_Spread','Away_Payout','Home','Home_Spread', 'Home_Payout', "Date"])#.replace('PK', 0)# .replace('-7½','-7.5')
df_future
# Out:
#              Away Away_Spread Away_Payout          Home Home_Spread  \
# 0         Chicago          -3        -110       Detroit          +3
# 1         Buffalo          +7        -113        Dallas          -7
# 2     New Orleans          -7        +104       Atlanta          +7
# 3    Philadelphia         -9½        -105         Miami         +9½
# 4       N.Y. Jets         -3½        +105    Cincinnati         +3½
# 5       Tennessee         +2½        +100  Indianapolis         -2½
# 6       Cleveland          -2        -105    Pittsburgh          +2
# 7      Washington         +10        -108      Carolina         -10
# 8       Green Bay         -6½        -105   N.Y. Giants         +6½
# 9   San Francisco          +6        -105     Baltimore          -6
# 10      Tampa Bay          +1        -105  Jacksonville          -1
# 11      L.A. Rams          -3        -105       Arizona          +3
# 12        Oakland         +9½        -102   Kansas City         -9½
# 13  L.A. Chargers         -2½        -120        Denver         +2½
# 14    New England          -3        -115       Houston          +3
# 15      Minnesota          +3        -110       Seattle          -3
#
#    Home_Payout        Date
# 0         +100  2019-11-28
# 1         +103  2019-11-28
# 2         -114  2019-11-28
# 3         -105  2019-12-01
# 4         -115  2019-12-01
# 5         -110  2019-12-01
# 6         -105  2019-12-01
# 7         -102  2019-12-01
# 8         -105  2019-12-01
# 9         -105  2019-12-01
# 10        -105  2019-12-01
# 11        -105  2019-12-01
# 12        -108  2019-12-01
# 13        +110  2019-12-01
# 14        +105  2019-12-01
# 15        +100  2019-12-02

# %%
all_games = pd.read_csv('allgames_v4.csv')

# %%
ag = np.sort(pd.Series(all_games['Team'].unique()).sort_values())
type(ag)
# Out:
# numpy.ndarray

# %%
odds_df = np.sort(df['Home'].unique())
odds_df_future = np.sort(df_future['Home'].unique())
print(len(odds_df))
print(len(odds_df_future))
# Out:
# 32
# 16

# %%
df_future
# Out:
#              Away Away_Spread Away_Payout          Home Home_Spread  \
# 0         Chicago          -3        -110       Detroit          +3
# 1         Buffalo          +7        -113        Dallas          -7
# 2     New Orleans          -7        +104       Atlanta          +7
# 3    Philadelphia         -9½        -105         Miami         +9½
# 4       N.Y. Jets         -3½        +105    Cincinnati         +3½
# 5       Tennessee         +2½        +100  Indianapolis         -2½
# 6       Cleveland          -2        -105    Pittsburgh          +2
# 7      Washington         +10        -108      Carolina         -10
# 8       Green Bay         -6½        -105   N.Y. Giants         +6½
# 9   San Francisco          +6        -105     Baltimore          -6
# 10      Tampa Bay          +1        -105  Jacksonville          -1
# 11      L.A. Rams          -3        -105       Arizona          +3
# 12        Oakland         +9½        -102   Kansas City         -9½
# 13  L.A. Chargers         -2½        -120        Denver         +2½
# 14    New England          -3        -115       Houston          +3
# 15      Minnesota          +3        -110       Seattle          -3
#
#    Home_Payout        Date
# 0         +100  2019-11-28
# 1         +103  2019-11-28
# 2         -114  2019-11-28
# 3         -105  2019-12-01
# 4         -115  2019-12-01
# 5         -110  2019-12-01
# 6         -105  2019-12-01
# 7         -102  2019-12-01
# 8         -105  2019-12-01
# 9         -105  2019-12-01
# 10        -105  2019-12-01
# 11        -105  2019-12-01
# 12        -108  2019-12-01
# 13        +110  2019-12-01
# 14        +105  2019-12-01
# 15        +100  2019-12-02

# %%
my_names = pd.Series(ag,index=odds_df).to_dict()
my_names
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8d0156641793> in <module>()
# ----> 1 my_names = pd.Series(ag,index=odds_df).to_dict()
#       2 my_names
#
# NameError: name 'pd' is not defined

# %%
df_future['Home'] = df_future['Home'].map(my_names)
df_future['Away'] = df_future['Away'].map(my_names)
df['Home'] = df['Home'].map(my_names)
df['Away'] = df['Away'].map(my_names)

# %%
def point5(s):
    return s.replace('½','.5').replace('+','')

# %%
#only run once
df_future['Home_Spread'] = df_future['Home_Spread'].apply(point5).astype(float)
df_future['Away_Spread'] = df_future['Away_Spread'].apply(point5).astype(float)
df_future['Home_Payout'] = df_future['Home_Payout'].apply(point5).astype(float)
df_future['Away_Payout'] = df_future['Away_Payout'].apply(point5).astype(float)

df['Home_Spread'] = df['Home_Spread'].apply(point5).astype(float)
df['Away_Spread'] = df['Away_Spread'].apply(point5).astype(float)
df['Home_Payout'] = df['Home_Payout'].apply(point5).astype(float)
df['Away_Payout'] = df['Away_Payout'].apply(point5).astype(float)

# %%
df.head()
# Out:
#                  Away  Away_Spread  Away_Payout                  Home  \
# 0   Green Bay Packers          3.5       -115.0         Chicago Bears
# 1  Kansas City Chiefs         -3.5        100.0  Jacksonville Jaguars
# 2    Los Angeles Rams         -1.5       -105.0     Carolina Panthers
# 3     Atlanta Falcons          3.5       -110.0     Minnesota Vikings
# 4    Tennessee Titans          5.5       -109.0      Cleveland Browns
#
#    Home_Spread  Home_Payout        Date
# 0         -3.5        105.0  2019-09-05
# 1          3.5       -110.0  2019-09-08
# 2          1.5       -105.0  2019-09-08
# 3         -3.5        100.0  2019-09-08
# 4         -5.5       -101.0  2019-09-08

# %%
df_future.head()
# Out:
#                   Away  Away_Spread  Away_Payout                Home  \
# 0        Chicago Bears         -3.0       -110.0       Detroit Lions
# 1        Buffalo Bills          7.0       -113.0      Dallas Cowboys
# 2        New York Jets         -7.0        104.0     Atlanta Falcons
# 3  Philadelphia Eagles         -9.5       -105.0      Miami Dolphins
# 4   New Orleans Saints         -3.5        105.0  Cincinnati Bengals
#
#    Home_Spread  Home_Payout        Date
# 0          3.0        100.0  2019-11-28
# 1         -7.0        103.0  2019-11-28
# 2          7.0       -114.0  2019-11-28
# 3          9.5       -105.0  2019-12-01
# 4          3.5       -115.0  2019-12-01

# %%
df.to_csv('past_2019.csv')
df_future.to_csv('future_2019.csv')
